# %% [markdown]
# # Handle Test Data of House Price Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
test_data=pd.read_csv('data/test.csv')
test_data.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_data.shape
# Out:
# (1459, 80)

# %%
test_data.info()  # to see column wise data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
# Display all columns
pd.set_option('display.max_columns', None)

# Display all rows
pd.set_option('display.max_rows', None)



test_data.isnull().sum()   # to see null values
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType        894
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# # Handling Missing values

# %% [markdown]
# # MSZoning
# have 4 missing values and its an object ( string ) with propably 3-4 category. So we will fill that with the most frequent cateogory or simply saying mode

# %%
mode_value = test_data['MSZoning'].mode()[0]
test_data['MSZoning'].fillna(mode_value, inplace=True)

# %% [markdown]
# # LotFrontage, MasVnrArea
#  data type is float. So filling the null values with their mean

# %%
# lotfrontage
mean_value = test_data['LotFrontage'].mean()
test_data['LotFrontage'].fillna(mean_value, inplace=True)

# MasVnrArea
test_data['MasVnrArea'].fillna(test_data['MasVnrArea'].mean(), inplace=True)

# %% [markdown]
# # Alley, PoolQC, Fence, MiscFeature
# have more than 80% missing values so drop it

# %%
columns_to_drop = ['Alley','PoolQC','Fence','MiscFeature']

#Drop columns
test_data  = test_data.drop(columns=columns_to_drop)

# %%
category=np.array(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
                   'BsmtFinType2', 'FireplaceQu','GarageType','GarageYrBlt',
                   'GarageFinish', 'GarageQual', 'GarageCond' ])


for element in category:
    test_data[element].fillna(test_data[element].mode()[0], inplace=True)

# %%
category2=['SaleType', 'GarageArea', 'GarageCars', 'Functional', 'KitchenQual',
 'BsmtHalfBath', 'BsmtFullBath','BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 
'BsmtFinSF1','Utilities','Exterior1st', 'Exterior2nd']


for elem in category2:
    test_data[elem].fillna(test_data[elem].mode()[0], inplace=True)

# %%
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
test=test_data

test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH    80.000000    11622   Pave      Reg
# 1  1462          20       RL    81.000000    14267   Pave      IR1
# 2  1463          60       RL    74.000000    13830   Pave      IR1
# 3  1464          60       RL    78.000000     9978   Pave      IR1
# 4  1465         120       RL    43.000000     5005   Pave      IR1
# 5  1466          60       RL    75.000000    10000   Pave      IR1
# 6  1467          20       RL    68.580357     7980   Pave      IR1
# 7  1468          60       RL    63.000000     8402   Pave      IR1
# 8  1469          20       RL    85.000000    10176   Pave      Reg
# 9  1470          20       RL    70.000000     8400   Pave      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# ...

# %%
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...
